# %%
stu1 = {
    '姓名':'陳怡伶',
    '國文':89,
    '英文':92,
    '數學':83,
    '地理':91,
    '歷史':65,
    }

stu2 = {
    '姓名':'馮芳如',
    '國文':92,
    '英文':75,
    '數學':92,
    '地理':89,
    '歷史':77,
    }

# %%
students = [stu1,stu2]
students
# Out:
# [{'姓名': '陳怡伶', '國文': 89, '英文': 92, '數學': 83, '地理': 91, '歷史': 65},
#  {'姓名': '馮芳如', '國文': 92, '英文': 75, '數學': 92, '地理': 89, '歷史': 77}]

# %%
from random import randint,choices

def getStudents(nums:int) -> list[dict]:  
    students:list[dict] = []
    with open('names.txt',mode='r',encoding='utf-8') as file:
        names:str = file.read()
    nameList:list[str] = names.split('\n')
    names:list[str] = choices(nameList,k=nums)

    for i in range(nums):
        stu = {
        '姓名':names[i],
        '國文':randint(45,100),
        '英文':randint(45,100),
        '數學':randint(45,100),
        '地理':randint(45,100),
        '歷史':randint(45,100),
        }
        students.append(stu)
        
    return students

students = getStudents(50)
students
# Out:
# [{'姓名': '蕭怡伶', '國文': 67, '英文': 67, '數學': 99, '地理': 56, '歷史': 83},
#  {'姓名': '趙家豪', '國文': 47, '英文': 88, '數學': 68, '地理': 55, '歷史': 98},
#  {'姓名': '吳麗卿', '國文': 68, '英文': 75, '數學': 72, '地理': 75, '歷史': 51},
#  {'姓名': '張莉雯', '國文': 92, '英文': 72, '數學': 84, '地理': 57, '歷史': 70},
#  {'姓名': '李政成', '國文': 49, '英文': 91, '數學': 52, '地理': 45, '歷史': 79},
#  {'姓名': '王雅慧', '國文': 72, '英文': 50, '數學': 51, '地理': 47, '歷史': 75},
#  {'姓名': '陳姵彬', '國文': 94, '英文': 60, '數學': 58, '地理': 83, '歷史': 61},
#  {'姓名': '楊偉翔', '國文': 54, '英文': 91, '數學': 94, '地理': 90, '歷史': 93},
#  {'姓名': '杜儀鳳', '國文': 85, '英文': 59, '數學': 45, '地理': 78, '歷史': 55},
#  {'姓名': '游淑惠', '國文': 54, '英文': 89, '數學': 76, '地理': 73, '歷史': 71},
#  {'姓名': '鄭淑珍', '國文': 49, '英文': 96, '數學': 96, '地理': 73, '歷史': 61},
#  {'姓名': '林益妏', '國文': 46, '英文': 78, '數學': 47, '地理': 45, '歷史': 87},
#  {'姓名': '林玉佩', '國文': 64, '英文': 49, '數學': 48, '地理': 94, '歷史': 99},
#  {'姓名': '張凱妮', '國文': 91, '英文': 99, '數學': 71, '地理': 90, '歷史': 47},
#  {'姓名': '張牧聿', '國文': 82, '英文': 71, '數學': 78, '地理': 87, '歷史': 91},
#  {'姓名': '鄭憲定', '國文': 76, '英文': 67, '數學': 87, '地理': 79, '歷史': 53},
#  {'姓名': '林希啟', '國文': 100, '英文': 55, '數學': 73, '地理': 89, '歷史': 81},
#  {'姓名': '李慈啟', '國文': 90, '英文': 89, '數學': 76, '地理': 62, '歷史': 45},
#  {'姓名': '簡美君', '國文': 58, '英文': 99, '數學': 98, '地理': 81, '歷史': 82},
#  {'姓名': '鄭淑珍', '國文': 60, '英文': 94, '數學': 85, '地理': 70, '歷史': 56},
#  {'姓名': '李湘婷', '國文': 74, '英文': 93, '數學': 73, '地理': 69, '歷史': 90},
#  {'姓名': '陳得映', '國文': 76, '英文': 73, '數學': 78, '地理': 69, '歷史': 88},
#  {'姓名': '陳向愛', '國文': 58, '英文': 90, '數學': 61, '地理': 60, '歷史': 94},
#  {'姓名': '余月修', '國文': 93, '英文': 74, '數學': 97, '地理': 91, '歷史': 65},
#  {'姓名': '黃佩芬', '國文': 59, '英文': 47, '數學': 86, '地理': 48, '歷史': 100},
#  {'姓名': '梁柏宇', '國文': 88, '英文': 83, '數學': 97, '地理': 68, '歷史': 47},
#  {'姓名': '郭淑枝', '國文': 64, '英文': 84, '數學': 65, '地理': 86, '歷史': 71},
#  {'姓名': '黎惠雯', '國文': 72, '英文': 53, '數學': 62, '地理': 63, '歷史': 69},
#  {'姓名': '沈心利', '國文': 62, '英文': 91, '數學': 65, '地理': 47, '歷史': 97},
#  {'姓名': '吳欣書', '國文': 54, '英文': 53, '數學': 94, '地理': 57, '歷史': 90},
#  {'姓名': '林益妏', '國文': 84, '英文': 82, '數學': 87, '地理': 55, '歷史': 58},
#  {'姓名': '葉祖雄', '國文': 72, '英文': 84, '數學': 72, '地理': 48, '歷史': 58},
#  {'姓名': '蔡欣汝', '國文': 59, '英文': 85, '數學': 63, '地理': 88, '歷史': 78},
#  {'姓名': '陳美惠', '國文': 73, '英文': 80, '數學': 71, '地理': 90, '歷史': 95},
#  {'姓名': '王坤安', '國文': 83, '英文': 56, '數學': 51, '地理': 98, '歷史': 57},
#  {'姓名': '李政白', '國文': 56, '英文': 95, '數學': 66, '地理': 89, '歷史': 57},
#  {'姓名': '陳倩潔', '國文': 95, '英文': 86, '數學': 92, '地理': 81, '歷史': 82},
#  {'姓名': '蘇凡菁', '國文': 50, '英文': 67, '數學': 72, '地理': 87, '歷史': 87},
#  {'姓名': '陳志偉', '國文': 90, '英文': 55, '數學': 89, '地理': 74, '歷史': 96},
#  {'姓名': '黃必琪', '國文': 48, '英文': 61, '數學': 78, '地理': 63, '歷史': 86},
#  {'姓名': '蒙淑惠', '國文': 78, '英文': 49, '數學': 55, '地理': 94, '歷史': 58},
#  {'姓名': '林康亮', '國文': 65, '英文': 78, '數學': 58, '地理': 62, '歷史': 93},
#  {'姓名': '張慧君', '國文': 63, '英文': 51, '數學': 52, '地理': 91, '歷史': 97},
#  {'姓名': '李慶亮', '國文': 65, '英文': 68, '數學': 91, '地理': 69, '歷史': 89},
#  {'姓名': '林群清', '國文': 62, '英文': 68, '數學': 85, '地理': 45, '歷史': 63},
#  {'姓名': '李彥伸', '國文': 86, '英文': 62, '數學': 84, '地理': 96, '歷史': 66},
#  {'姓名': '尚偉倫', '國文': 92, '英文': 89, '數學': 89, '地理': 65, '歷史': 65},
#  {'姓名': '王雅慧', '國文': 80, '英文': 78, '數學': 80, '地理': 89, '歷史': 71},
#  {'姓名': '楊偉翔', '國文': 64, '英文': 48, '數學': 63, '地理': 100, '歷史': 73},
#  {'姓名': '賴苑禾', '國文': 76, '英文': 45, '數學': 53, '地理': 59, '歷史': 97}]
